# %%
twitter_data_dump = "~/Downloads/account_analytics_content_2025-04-02_2025-06-30.csv"
linkedin_data_dump = "~/Downloads/Content_2025-04-02_2025-06-30_SkylarPayne.xlsx"

# %%
import pandas as pd

df_twitter = pd.read_csv("~/Downloads/account_analytics_content_2025-04-02_2025-06-30.csv")
df_twitter.head()
# Out:
#         Post id               Date  \
# 0  1.939740e+18  Mon, Jun 30, 2025
# 1  1.939738e+18  Mon, Jun 30, 2025
# 2  1.939737e+18  Mon, Jun 30, 2025
# 3  1.939737e+18  Mon, Jun 30, 2025
# 4  1.939737e+18  Mon, Jun 30, 2025
#
#                                            Post text  \
# 0                   @intellectronica I feel the same
# 1                         @Yuchenj_UW cc @gemisisDev
# 2   @caluckenbach but how do you know which is which
# 3  @intellectronica Do you think less technical p...
# 4  @bradthilton we are reaching the point where A...
#
#                                            Post Link  Impressions  Likes  \
# 0  https://x.com/skylar_b_payne/status/1939739998...            8      1
# 1  https://x.com/skylar_b_payne/status/1939737621...          137      1
# 2  https://x.com/skylar_b_payne/status/1939737300...           12      1
# 3  https://x.com/skylar_b_payne/status/1939737186...           19      0
# ...

# %%
import pandas as pd

df_linkedin = pd.read_excel("~/Downloads/Content_2025-04-02_2025-06-30_SkylarPayne.xlsx")
df_linkedin.head()
# Out:
# /Users/skylarbpayne/projects/ai-livestreams/.venv/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   Overall Performance  4/2/2025 - 6/30/2025
# 0         Impressions                 65145
# 1     Members reached                 16295
